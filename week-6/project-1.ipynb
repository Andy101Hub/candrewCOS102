# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk

def welcomemessage(name, weight, location):
    # Create a Tkinter window
    window = tk.Toplevel(root)
    window.title("Simi Services")
    window.geometry("500x200")

    label_1 = tk.Label(window, text=f"Welcome {name}\n")
    label_1.pack()
    label_2 = tk.Label(window, text="This is a delivery service called Simi Services")
    label_2.pack()

    if weight >= 10 and location == "ibeju lekki community" or "ibeju-lekki community":
        delivery_fee_label = tk.Label(window, text="Your delivery fee is N5000")
    elif weight < 10 and location == "ibeju lekki community":
        delivery_fee_label = tk.Label(window, text="Your delivery fee is N3500")
    elif weight >=10 and location  == "epe":
        delivery_fee_label = tk.Label(window, text="Your delivery fee is N10000")
    elif weight <10 and location == "epe":
        delivery_fee_label = tk.Label(window, text="Your delivery fee is N5000")
        
    delivery_fee_label.pack()

    # Run the Tkinter event lopp
    root.mainloop()

def submit():
    name = name_entry.get()
    weight = int(weight_entry.get())
    location = location_entry.get().lower()

    
    welcomemessage(name, weight, location)

    #inside this function is where we put the conditions don't forget

# Create main window 
root = tk.Tk()
root.title("Customer Form")
root.geometry("500x200")

# Create name label and entry
name_label = tk.Label(root, text="NAME:")
name_label.pack()
name_entry = tk.Entry(root)
name_entry.pack()

# Create weight label and entry
weight_label = tk.Label(root, text="PACKAGE WEIGHT(KG):")
weight_label.pack()
weight_entry = tk.Entry(root)
weight_entry.pack()

# Create location label and entry
location_label = tk.Label(root, text="LOCATION:")
location_label.pack()
location_entry = tk.Entry(root, width=25)
location_entry.pack()

# Create submit button
submit_button = tk.Button(root, text="Submit", command=submit)
submit_button.pack()

# Run the main event loop
root.mainloop()
