# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk

name_entry = None
score_entry = None
credits_entry = None
interview_label = None

def welcomemessage_1():
    global name_entry, score_entry, credits_entry, interview_var
    # Create a Tkinter window
    window = tk.Toplevel(root)
    window.title("Computer Science Form")
    window.geometry("700x500")

    # Create name label and entry
    name_label = tk.Label(window, text="NAME:")
    name_label.pack()
    name_entry = tk.Entry(window)
    name_entry.pack()
    
    # Create score label and entry
    score_label = tk.Label(window, text="ENTER JAMB SCORE:")
    score_label.pack()
    score_entry = tk.Entry(window)
    score_entry.pack()
    
    # Create credits label and entry
    credits_label = tk.Label(window, text="How many credits do you have:")
    credits_label.pack()
    credits_entry = tk.Entry(window)
    credits_entry.pack()

    # Create interview label and entry
    interview_var = tk.BooleanVar()
    interview_label = tk.Checkbutton(window, text="Passed interview", variable=interview_var)
    interview_label.pack()

    submit_button = tk.Button(window, text="Submit", command=submit_2)
    submit_button.pack()

    root.mainloop()
    
   

def welcomemessage_2():
    global name_entry, score_entry, credits_entry, interview_var
    # Create a Tkinter window
    window = tk.Toplevel(root)
    window.title("Mass Communication Form")
    window.geometry("700x500")

     # Create name label and entry
    name_label = tk.Label(window, text="NAME:")
    name_label.pack()
    name_entry = tk.Entry(window)
    name_entry.pack()
    
    # Create score label and entry
    score_label = tk.Label(window, text="ENTER JAMB SCORE:")
    score_label.pack()
    score_entry = tk.Entry(window)
    score_entry.pack()
    
    # Create credits label and entry
    credits_label = tk.Label(window, text="How many credits do you have:")
    credits_label.pack()
    credits_entry = tk.Entry(window)
    credits_entry.pack()

    # Create interview label and entry
    interview_var = tk.BooleanVar()
    interview_label = tk.Checkbutton(window, text="Passed interview", variable=interview_var)
    interview_label.pack()

    submit_button = tk.Button(window, text="Submit", command=submit_3)
    submit_button.pack()
    
    # Run the Tkinter event lopp
    root.mainloop()



def submit_1():

    department = department_entry.get()
    if department == "computer science":
        welcomemessage_1()
    elif department == "mass communication":
        welcomemessage_2()
    
def submit_2():
    
    # Get data from entries
    name = name_entry.get()
    jamb_score = int(score_entry.get())  # Assuming JAMB score is an integer
    credits = int(credits_entry.get())   # Assuming credits are an integer
    passed_interview = interview_var.get()  # Assuming interview status is retrieved from the Checkbutton state

    # Check admission criteria
    if jamb_score >= 250 and credits >= 5 and passed_interview:
        messagebox.showinfo("Admission Status", f"Congratulations {name}! You are admitted to Computer Science.")
    else:
        messagebox.showinfo("Admission Status", f"Sorry {name}, you are not admitted to Computer Science.")
    welcomemessage_1()

def submit_3():
   
     # Get data from entries
    name = name_entry.get()
    jamb_score = int(score_entry.get())  # Assuming JAMB score is an integer
    credits = int(credits_entry.get())   # Assuming credits are an integer
    passed_interview = interview_var.get()  # Assuming interview status is retrieved from the Checkbutton state

    # Check admission criteria for Mass Communication
    if jamb_score >= 230 and credits >= 5 and passed_interview:
        messagebox.showinfo("Admission Status", f"Congratulations {name}! You are admitted to Mass Communication.")
    else:
        messagebox.showinfo("Admission Status", f"Sorry {name}, you are not admitted to Mass Communication.")
    welcomemessage_2()
    

# Create main window 
root = tk.Tk()
root.title("Student Form")
root.geometry("500x200")

# Create department label and entry
department_label = tk.Label(root, text="Input Department")
department_label.pack()
department_entry = tk.Entry(root)
department_entry.pack()




# Create submit button
submit_button = tk.Button(root, text="Submit", command=submit_1)
submit_button.pack()

# Run the main event loop
root.mainloop()
