# %%
import tkinter as tk
from tkinter import *


def button_clicked():
    
    customer_name = name_entry.get()

    total_bill = calculate_total_bill()

    if total_bill > 1000 and total_bill < 2500:
        discount = 0.1  
    elif total_bill > 2500 and total_bill < 5000:
        discount = 0.15  
    elif total_bill > 5000:
        discount = 0.25
    elif total_bill < 1000:
        discount = 0
        
    
    discounted_bill = total_bill - (total_bill * discount)
   
    bill_window = Toplevel()
    bill_window.title("Total Bill")
    bill_window.geometry("500x300")

    customer_label = Label(bill_window, text=f"Customer Name: {customer_name}", font=("Arial", 15))
    customer_label.grid(row=0, column=0, pady=5)
    
    bills_label = Label(bill_window, text=f"Your total bill: N{total_bill}", font=("Arial", 15))
    bills_label.grid(row=2, column=0)

    discount_label = Label(bill_window, text=f"Discount applied: {discount*100}%", font=("Arial", 15))
    discount_label.grid(row=3, column=0)
    
    discounted_label = Label(bill_window, text=f"Total bill after discount: N{discounted_bill}", font=("Arial", 15))
    discounted_label.grid(row=4, column=0)


def calculate_total_bill():
    
    jollofrice_total = int(jollofrice_sb.get()) * 350
    coconutrice_total = int(coconutrice_sb.get()) * 350
    jspag_total = int(jspag_sb.get()) * 350
    savbeans_total = int(savbeans_sb.get()) * 350
    potatoes_total = int(potatoes_sb.get()) * 300
    plantains_total = int(plantains_sb.get()) * 150
    mixedveggies_total = int(mixedveggies_sb.get()) * 150
    yam_total = int(yam_sb.get()) * 150
    eba_total = int(eba_sb.get()) * 100
    poundo_total = int(poundo_sb.get()) * 100
    semo_total = int(semo_sb.get()) * 100
    akama_total = int(akama_sb.get()) * 450
    egusi_total = int(egusi_sb.get()) * 480
    chillichicken_total = int(chillichicken_sb.get()) * 1100
    grilledchicken_total = int(grilledchicken_sb.get()) * 400
    beef_total = int(beef_sb.get()) * 400
    fish_total = int(fish_sb.get()) * 500
    egg_total = int(egg_sb.get()) * 200
    sausages_total = int(sausages_sb.get()) * 200
    water_total = int(water_sb.get()) * 200
    glassdrink_total = int(glassdrink_sb.get()) * 150
    petdrink1_total = int(petdrink1_sb.get()) * 300
    petdrink2_total = int(petdrink2_sb.get()) * 350
    malt_total = int(malt_sb.get()) * 500
    freshyo_total = int(freshyo_sb.get()) * 600
    pineapple_total = int(pineapple_sb.get()) * 350
    mango_total = int(mango_sb.get()) * 350
    zobo_total = int(zobo_sb.get()) * 350

    total_bill = (
        jollofrice_total + coconutrice_total + jspag_total + savbeans_total + potatoes_total + plantains_total +
        mixedveggies_total + yam_total + eba_total + poundo_total + semo_total + akama_total + egusi_total +
        chillichicken_total + grilledchicken_total + beef_total + fish_total + egg_total + sausages_total +
        water_total + glassdrink_total + petdrink1_total + petdrink2_total + malt_total + freshyo_total +
        pineapple_total + mango_total + zobo_total
    )
    return total_bill


   

window = Tk()
window.title("MENU")
window.minsize(width=800,height=700)
window.configure(bg="tomato")
    

restaurant_name = Label(text='PAU CAFETERIA MENU', font=('Algerian', 20, "bold"), bg="tomato")
restaurant_name.grid(column=1, row=0)

quote = Label(text="We serve quality perfection MEALS!!", font=('Algerian', 15, "italic"), bg="tomato")
quote.grid(column=1, row=2)

food_label = Label(text="Kindly choose your meal", font=('Arial', 12), bg="tomato")
food_label.grid(column=1, row=3)

label_1 = Label(text="RICE/PASTA", font=('Algerian', 15), bg="tomato")
label_1.grid(sticky=W)

jollofrice_label = Label(text="Jollof rice", font=('Arial', 10), bg="tomato")
jollofrice_label.grid(sticky=W)
jollofrice_sb = Spinbox(from_=0, to=100, width=5)
jollofrice_sb.place(x=165, y=115)

label_3 = Label(text="N350", font=('Arial', 10), bg="tomato")
label_3.place(x=120,y=115)

coconutrice_label = Label(text="Coconut Fried Rice", font=('Arial', 10), bg="tomato")
coconutrice_label.grid(sticky=W)
coconutrice_sb = Spinbox(from_=0, to=100, width=5)
coconutrice_sb.place(x=165, y=140)

label_5 = Label(text="N350", font=('Arial', 10), bg="tomato")
label_5.place(x=120, y=139)

jspag_label = Label(text="Jollof Spaghetti", font=('Arial', 10), bg="tomato")
jspag_label.grid(sticky=W)
jspag_sb = Spinbox(from_=0, to=100, width=5)
jspag_sb.place(x=165, y=163)

label_6 = Label(text="N350", font=('Arial', 10), bg="tomato")
label_6.place(x=120, y=160)

label_7 = Label(text="SIDE DISHES", font=('Algerian', 15), bg="tomato")
label_7.grid(sticky=W, pady=30)

savbeans_label = Label(text="Savoury Beans", font=('Arial', 10), bg="tomato")
savbeans_label.place(x=0, y=237)
savbeans_sb = Spinbox(from_=0, to=100, width=5)
savbeans_sb.place(x=190, y=236)

label_9 = Label(text="N350", font=('Arial', 10), bg="tomato")
label_9.place(x=150, y=237)

potatoes_label = Label(text="Roasted Sweet Potatoes", font=('Arial', 10), bg="tomato")
potatoes_label.place(x=0, y=260)
potatoes_sb = Spinbox(from_=0, to=100, width=5)
potatoes_sb.place(x=190, y=258)

label_11 = Label(text="N300", font=('Arial', 10), bg="tomato")
label_11.place(x=150, y=260)

plantains_label = Label(text="Fried Plantains", font=('Arial', 10), bg="tomato")
plantains_label.place(x=0, y=280)
plantains_sb = Spinbox(from_=0, to=100, width=5)
plantains_sb.place(x=190, y=279)

label_13 = Label(text="N150", font=('Arial', 10), bg="tomato")
label_13.place(x=150, y=280)

mixedveggies_label = Label(text="Mixed Vegetable Salad", font=('Arial', 10), bg="tomato")
mixedveggies_label.place(x=0, y=300)
mixedveggies_sb = Spinbox(from_=0, to=100, width=5)
mixedveggies_sb.place(x=190, y=300)

label_15 = Label(text="N150", font=('Arial', 10), bg="tomato")
label_15.place(x=150, y=300)

yam_label = Label(text="Boiled Yam", font=('Arial', 10), bg="tomato")
yam_label.place(x=0, y=320)
yam_sb = Spinbox(from_=0, to=100, width=5)
yam_sb.place(x=190, y=320)

label_15 = Label(text="N150", font=('Arial', 10), bg="tomato")
label_15.place(x=150, y=320)

label_1 = Label(text="SOUPS & SWALLOWS", font=('Algerian', 15), bg="tomato")
label_1.grid(sticky=W, pady=90)

eba_label = Label(text="Eba", font=('Arial', 10), bg="tomato")
eba_label.place(x=0, y=387)
eba_sb = Spinbox(from_=0, to=100, width=5)
eba_sb.place(x=190, y=385)

label_9 = Label(text="N100", font=('Arial', 10), bg="tomato")
label_9.place(x=150, y=385)

poundo_label = Label(text="Poundo Yam", font=('Arial', 10), bg="tomato")
poundo_label.place(x=0, y=410)
poundo_sb = Spinbox(from_=0, to=100, width=5)
poundo_sb.place(x=190, y=408)

label_11 = Label(text="N100", font=('Arial', 10), bg="tomato")
label_11.place(x=150, y=408)

semo_label = Label(text="Semo", font=('Arial', 10), bg="tomato")
semo_label.place(x=0, y=430)
semo_sb = Spinbox(from_=0, to=100, width=5)
semo_sb.place(x=190, y=429)

label_13 = Label(text="N100", font=('Arial', 10), bg="tomato")
label_13.place(x=150, y=429)

akama_label = Label(text="Akama Soup", font=('Arial', 10), bg="tomato")
akama_label.place(x=0, y=450)
akama_sb = Spinbox(from_=0, to=100, width=5)
akama_sb.place(x=190, y=450)

label_15 = Label(text="N450", font=('Arial', 10), bg="tomato")
label_15.place(x=150, y=450)

egusi_label = Label(text="Egusi Soup", font=('Arial', 10), bg="tomato")
egusi_label.place(x=0, y=470)
egusi_sb = Spinbox(from_=0, to=100, width=5)
egusi_sb.place(x=190, y=470)

label_15 = Label(text="N480", font=('Arial', 10), bg="tomato")
label_15.place(x=150, y=470)

label_1 = Label(text="PROTEINS", font=('Algerian', 15), bg="tomato")
label_1.place(x=550, y=80)

chillichicken_label = Label(text="Sweet Chilli Chicken", font=('Arial', 10), bg="tomato")
chillichicken_label.place(x=550, y=100)
chillichicken_sb = Spinbox(from_=0, to=100, width=5)
chillichicken_sb.place(x=753, y=100)

label_15 = Label(text="N1110", font=('Arial', 10), bg="tomato")
label_15.place(x=700, y=100)

grilledchicken_label = Label(text="Grilled Chicken Wings", font=('Arial', 10), bg="tomato")
grilledchicken_label.place(x=550, y=120)
grilledchicken_sb = Spinbox(from_=0, to=100, width=5)
grilledchicken_sb.place(x=753, y=122)

label_15 = Label(text="N400", font=('Arial', 10), bg="tomato")
label_15.place(x=700, y=120)

beef_label = Label(text="Fried Beef", font=('Arial', 10), bg="tomato")
beef_label.place(x=553, y=140)
beef_sb = Spinbox(from_=0, to=100, width=5)
beef_sb.place(x=753, y=143)

label_15 = Label(text="N400", font=('Arial', 10), bg="tomato")
label_15.place(x=700, y=140)

fish_label = Label(text="Fried Fish", font=('Arial', 10), bg="tomato")
fish_label.place(x=553, y=160)
fish_sb = Spinbox(from_=0, to=100, width=5)
fish_sb.place(x=753, y=163)

label_15 = Label(text="N500", font=('Arial', 10), bg="tomato")
label_15.place(x=700, y=160)

egg_label = Label(text="Boiled Egg", font=('Arial', 10), bg="tomato")
egg_label.place(x=553, y=180)
egg_sb = Spinbox(from_=0, to=100, width=5)
egg_sb.place(x=753, y=184)

label_15 = Label(text="N200", font=('Arial', 10), bg="tomato")
label_15.place(x=700, y=180)

sausages_label = Label(text="Sauteed Sausages", font=('Arial', 10), bg="tomato")
sausages_label.place(x=553, y=200)
sausages_sb = Spinbox(from_=0, to=100, width=5)
sausages_sb.place(x=753, y=205)

label_15 = Label(text="N200", font=('Arial', 10), bg="tomato")
label_15.place(x=700, y=200)

label_1 = Label(text="BEVERAGES", font=('Algerian', 15), bg="tomato")
label_1.place(x=550, y=250)

water_label = Label(text="Water", font=('Arial', 10), bg="tomato")
water_label.place(x=553, y=277)
water_sb = Spinbox(from_=0, to=100, width=5)
water_sb.place(x=753, y=277)

label_15 = Label(text="N200", font=('Arial', 10), bg="tomato")
label_15.place(x=700, y=277)

glassdrink_label = Label(text="Glass Drink(35cl)", font=('Arial', 10), bg="tomato")
glassdrink_label.place(x=553, y=300)
glassdrink_sb = Spinbox(from_=0, to=100, width=5)
glassdrink_sb.place(x=753, y=298)

label_15 = Label(text="N150", font=('Arial', 10), bg="tomato")
label_15.place(x=700, y=298)

petdrink1_label = Label(text="PET Drink(35cl)", font=('Arial', 10), bg="tomato")
petdrink1_label.place(x=553, y=320)
petdrink1_sb = Spinbox(from_=0, to=100, width=5)
petdrink1_sb.place(x=753, y=319)

label_15 = Label(text="N300", font=('Arial', 10), bg="tomato")
label_15.place(x=700, y=319)

petdrink2_label = Label(text="PET Drink(50cl)", font=('Arial', 10), bg="tomato")
petdrink2_label.place(x=553, y=340)
petdrink2_sb = Spinbox(from_=0, to=100, width=5)
petdrink2_sb.place(x=753, y=339)

label_15 = Label(text="N350", font=('Arial', 10), bg="tomato")
label_15.place(x=700, y=339)

malt_label = Label(text="Glass/Canned Malt", font=('Arial', 10), bg="tomato")
malt_label.place(x=553, y=360)
malt_sb = Spinbox(from_=0, to=100, width=5)
malt_sb.place(x=753, y=360)

label_15 = Label(text="N500", font=('Arial', 10), bg="tomato")
label_15.place(x=700, y=360)

freshyo_label = Label(text="Fresh Yo", font=('Arial', 10), bg="tomato")
freshyo_label.place(x=553, y=380)
freshyo_sb = Spinbox(from_=0, to=100, width=5)
freshyo_sb.place(x=753, y=380)

label_15 = Label(text="N600", font=('Arial', 10), bg="tomato")
label_15.place(x=700, y=380)

pineapple_label = Label(text="Pineapple Juice", font=('Arial', 10), bg="tomato")
pineapple_label.place(x=553, y=400)
pineapple_sb = Spinbox(from_=0, to=100, width=5)
pineapple_sb.place(x=753, y=400)

label_15 = Label(text="N350", font=('Arial', 10), bg="tomato")
label_15.place(x=700, y=400)

mango_label = Label(text="Mango Juice", font=('Arial', 10), bg="tomato")
mango_label.place(x=553, y=420)
mango_sb = Spinbox(from_=0, to=100, width=5)
mango_sb.place(x=753, y=420)

label_15 = Label(text="N350", font=('Arial', 10), bg="tomato")
label_15.place(x=700, y=420)

zobo_label = Label(text="Zobo Drink", font=('Arial', 10), bg="tomato")
zobo_label.place(x=553, y=440)
zobo_sb = Spinbox(from_=0, to=100, width=5)
zobo_sb.place(x=753, y=440)

label_15 = Label(text="N350", font=('Arial', 10), bg="tomato")
label_15.place(x=700, y=450,)

name_label = Label(text="Enter Your Name:", font=('Arial', 12), bg="tomato")
name_label.place(x=0, y=520)
name_entry = Entry(window, font=('Arial', 12), width=20)
name_entry.place(x=130, y=520)

finish = Button(text="Order", command=button_clicked, width=10)
finish.place(x=0, y=565)
window.mainloop()
